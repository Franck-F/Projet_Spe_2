# %% [markdown]
# # Phase 3 : Modélisation au Niveau Patch
#
# ## Objectifs
# - Entraîner un modèle baseline
# - Transfer learning avec architectures pré-entraînées
# - Optimisation des hyperparamètres
# - Évaluation des performances

# %%
# Imports
import torch
import torch.nn as nn
from torch.utils.data import DataLoader
import plotly.express as px

import sys
sys.path.append('..')
from src.models.cnn_baseline import BaselineCNN
from src.models.transfer_learning import get_pretrained_model
from src.models.train import Trainer
from src.utils.config import load_config

config = load_config('../configs/config.yaml')

# %% [markdown]
# ## 1. Baseline Model

# %%
# TODO: Créer et entraîner CNN baseline
# TODO: Évaluer les performances

# %% [markdown]
# ## 2. Transfer Learning

# %%
# TODO: Tester ResNet50, EfficientNet, DenseNet
# TODO: Fine-tuning progressif

# %% [markdown]
# ## 3. Optimisation

# %%
# TODO: Grid search hyperparamètres
# TODO: Courbes d'apprentissage
