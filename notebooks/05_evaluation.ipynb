# %% [markdown]
# # Phase 5 : Évaluation et Interprétabilité
#
# ## Objectifs
# - Évaluation complète des modèles
# - Analyse du domain shift
# - Interprétabilité avec Grad-CAM
# - Discussion éthique et limites

# %%
# Imports
import numpy as np
import plotly.express as px
import plotly.graph_objects as go

import sys
sys.path.append('..')
from src.evaluation.metrics import compute_all_metrics, plot_confusion_matrix
from src.evaluation.interpretability import visualize_gradcam
from src.utils.config import load_config

config = load_config('../configs/config.yaml')

# %% [markdown]
# ## 1. Métriques de Performance

# %%
# TODO: Calculer toutes les métriques
# TODO: Niveau patch et patient

# %% [markdown]
# ## 2. Analyse Domain Shift

# %%
# TODO: Performances par hôpital
# TODO: Identifier les causes

# %% [markdown]
# ## 3. Interprétabilité

# %%
# TODO: Grad-CAM sur cas représentatifs
# TODO: Analyse des erreurs

# %% [markdown]
# ## 4. Discussion et Limites

# %%
# TODO: Biais potentiels
# TODO: Recommandations cliniques
