# %% [markdown]
# # Phase 2 : Prétraitement des Données
#
# ## Objectifs
# - Normalisation de la coloration H&E
# - Augmentation de données
# - Gestion du déséquilibre des classes
# - Création des datasets train/val/test

# %%
# Imports
import numpy as np
import cv2
from pathlib import Path
import albumentations as A

import sys
sys.path.append('..')
from src.data.preprocessing import StainNormalizer, create_augmentation_pipeline
from src.utils.config import load_config

config = load_config('../configs/config.yaml')

# %% [markdown]
# ## 1. Normalisation de Coloration

# %%
# TODO: Implémenter normalisation Macenko/Reinhard
# TODO: Tester sur échantillons de différents hôpitaux

# %% [markdown]
# ## 2. Augmentation de Données

# %%
# TODO: Définir pipeline d'augmentation
# TODO: Visualiser les transformations

# %% [markdown]
# ## 3. Split Train/Val/Test

# %%
# TODO: Stratification au niveau patient
# TODO: Vérifier la distribution
