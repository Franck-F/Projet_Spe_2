# %% [markdown]
# # Phase 4 : Agrégation Patch → Patient
#
# ## Objectifs
# - Agréger les prédictions au niveau patch
# - Prédire le stade pN au niveau patient
# - Comparer différentes stratégies d'agrégation

# %%
# Imports
import numpy as np
import pandas as pd
import plotly.express as px

import sys
sys.path.append('..')
from src.models.aggregation import StatisticalAggregator, MLAggregator
from src.utils.config import load_config

config = load_config('../configs/config.yaml')

# %% [markdown]
# ## 1. Agrégation Statistique

# %%
# TODO: Calculer % patchs tumoraux par patient
# TODO: Définir seuils pour classification pN

# %% [markdown]
# ## 2. Modèle ML de Second Niveau

# %%
# TODO: Extraire features agrégées
# TODO: Entraîner XGBoost/Random Forest

# %% [markdown]
# ## 3. Comparaison des Approches

# %%
# TODO: Évaluer chaque stratégie
# TODO: Visualiser les résultats
